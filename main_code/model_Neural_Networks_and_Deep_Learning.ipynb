# %%
# import the library
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read CSV file 
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head(10)
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
# 5       CONFIRMED              0              0              0              0
# 6       CONFIRMED              0              0              0              0
# 7       CONFIRMED              0              0              0              0
# 8       CONFIRMED              0              1              0              0
# 9       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
# 5    2.566589     1.780000e-05    -1.780000e-05   179.554370
# 6   16.068647     1.090000e-05    -1.090000e-05   173.621937
# 7    2.470613     2.700000e-08    -2.700000e-08   122.763305
# 8    2.204735     4.300000e-08    -4.300000e-08   121.358542
# 9    3.522498     1.980000e-07    -1.980000e-07   121.119423
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
# 5          0.004610  ...            -232      4.486           0.054
# 6          0.000517  ...             -83      4.485           0.083
# 7          0.000009  ...             -78      4.457           0.024
# 8          0.000016  ...             -89      4.019           0.033
# 9          0.000047  ...            -137      4.169           0.055
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
# 5          -0.229     0.972          0.315         -0.105  296.28613
# 6          -0.028     0.848          0.033         -0.072  286.99948
# 7          -0.024     0.964          0.038         -0.038  286.80847
# 8          -0.027     1.952          0.099         -0.110  292.24728
# 9          -0.045     1.451          0.110         -0.110  281.28812
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
# 5  48.224670      15.714
# 6  48.375790      15.841
# 7  49.316399      11.338
# 8  47.969521      10.463
# 9  42.451080      13.563
#
# [10 rows x 41 columns]

# %%
# Visualizing data

# %% [markdown]
# # Select features (columns)

# %%
# Set features
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 2700              0              0              0              0   31.804760
# 21                0              0              0              0    4.280964
# 5040              0              1              1              0    0.829019
# 2795              0              0              1              0    1.387838
# 1765              0              0              0              0   14.383227
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 2700         0.000091        -0.000091    190.25413           0.00224
# 21           0.000006        -0.000006    171.89659           0.00115
# 5040         0.000002        -0.000002    131.46667           0.00401
# 2795         0.000006        -0.000006    132.11351           0.00318
# 1765         0.000086        -0.000086    140.57648           0.00530
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 2700          -0.00224  ...            -128      4.235           0.143
# 21            -0.00115  ...            -169      4.564           0.032
# 5040          -0.00401  ...            -255      4.271           0.124
# 2795          -0.00318  ...            -219      4.442           0.054
# 1765          -0.00530  ...            -135      4.249           0.137
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 2700          -0.117     1.356          0.212         -0.259  287.62082
# 21            -0.168     0.831          0.207         -0.069  294.26581
# 5040          -0.186     1.328          0.408         -0.220  296.03485
# 2795          -0.216     1.044          0.335         -0.112  295.64212
# 1765          -0.112     1.291          0.216         -0.216  290.08276
#
#             dec  koi_kepmag
# 2700  43.141647      13.178
# 21    49.314091      15.356
# 5040  45.490822      14.661
# 2795  48.773071      15.167
# 1765  50.863480      13.312
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# C:\Users\ofunk\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# # Train Model - Neural Network
# Use `Neural Network` model

# %%
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Label encoder
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
print(label_encoder.classes_)
# Out:
# ['CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE']

# %%
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)
pd.plotting.scatter_matrix(X, c=encoded_y, figsize=(40, 40));

# %%
# first, create a normal neural network 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 443
# Trainable params: 443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 1s - loss: 0.9700 - accuracy: 0.4534
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.7166 - accuracy: 0.6943
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.5382 - accuracy: 0.7765
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.4488 - accuracy: 0.7961
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.4105 - accuracy: 0.8062
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3902 - accuracy: 0.8112
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3768 - accuracy: 0.8190
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3679 - accuracy: 0.8259
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3605 - accuracy: 0.8270
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3547 - accuracy: 0.8270
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3498 - accuracy: 0.8327
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3458 - accuracy: 0.8316
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3413 - accuracy: 0.8430
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3364 - accuracy: 0.8407
# Epoch 15/100
# 5243/5243 - 0s - loss: 0.3338 - accuracy: 0.8446
# Epoch 16/100
# 5243/5243 - 0s - loss: 0.3310 - accuracy: 0.8491
# Epoch 17/100
# 5243/5243 - 0s - loss: 0.3282 - accuracy: 0.8493
# Epoch 18/100
# 5243/5243 - 0s - loss: 0.3248 - accuracy: 0.8512
# Epoch 19/100
# 5243/5243 - 0s - loss: 0.3219 - accuracy: 0.8541
# Epoch 20/100
# 5243/5243 - 0s - loss: 0.3203 - accuracy: 0.8570
# Epoch 21/100
# 5243/5243 - 0s - loss: 0.3170 - accuracy: 0.8568
# Epoch 22/100
# 5243/5243 - 0s - loss: 0.3158 - accuracy: 0.8587
# Epoch 23/100
# 5243/5243 - 0s - loss: 0.3136 - accuracy: 0.8631
# Epoch 24/100
# 5243/5243 - 0s - loss: 0.3109 - accuracy: 0.8611
# Epoch 25/100
# 5243/5243 - 0s - loss: 0.3089 - accuracy: 0.8638
# Epoch 26/100
# 5243/5243 - 0s - loss: 0.3085 - accuracy: 0.8648
# Epoch 27/100
# 5243/5243 - 0s - loss: 0.3084 - accuracy: 0.8644
# Epoch 28/100
# 5243/5243 - 0s - loss: 0.3065 - accuracy: 0.8650
# Epoch 29/100
# 5243/5243 - 0s - loss: 0.3042 - accuracy: 0.8680
# Epoch 30/100
# 5243/5243 - 0s - loss: 0.3019 - accuracy: 0.8693
# Epoch 31/100
# 5243/5243 - 0s - loss: 0.3018 - accuracy: 0.8684
# Epoch 32/100
# 5243/5243 - 0s - loss: 0.3013 - accuracy: 0.8638
# Epoch 33/100
# 5243/5243 - 0s - loss: 0.3009 - accuracy: 0.8688
# Epoch 34/100
# 5243/5243 - 0s - loss: 0.2983 - accuracy: 0.8716
# Epoch 35/100
# 5243/5243 - 0s - loss: 0.2990 - accuracy: 0.8701
# Epoch 36/100
# 5243/5243 - 0s - loss: 0.2983 - accuracy: 0.8697
# Epoch 37/100
# 5243/5243 - 0s - loss: 0.2966 - accuracy: 0.8669
# Epoch 38/100
# 5243/5243 - 0s - loss: 0.2966 - accuracy: 0.8701
# Epoch 39/100
# 5243/5243 - 0s - loss: 0.2946 - accuracy: 0.8711
# Epoch 40/100
# 5243/5243 - 0s - loss: 0.2934 - accuracy: 0.8705
# Epoch 41/100
# 5243/5243 - 0s - loss: 0.2951 - accuracy: 0.8690
# Epoch 42/100
# 5243/5243 - 0s - loss: 0.2931 - accuracy: 0.8722
# Epoch 43/100
# 5243/5243 - 0s - loss: 0.2915 - accuracy: 0.8722
# Epoch 44/100
# 5243/5243 - 0s - loss: 0.2909 - accuracy: 0.8743
# Epoch 45/100
# 5243/5243 - 0s - loss: 0.2904 - accuracy: 0.8732
# Epoch 46/100
# 5243/5243 - 0s - loss: 0.2894 - accuracy: 0.8755
# Epoch 47/100
# 5243/5243 - 0s - loss: 0.2897 - accuracy: 0.8724
# Epoch 48/100
# 5243/5243 - 0s - loss: 0.2886 - accuracy: 0.8755
# Epoch 49/100
# 5243/5243 - 0s - loss: 0.2876 - accuracy: 0.8764
# Epoch 50/100
# 5243/5243 - 0s - loss: 0.2879 - accuracy: 0.8753
# Epoch 51/100
# 5243/5243 - 0s - loss: 0.2853 - accuracy: 0.8755
# Epoch 52/100
# 5243/5243 - 0s - loss: 0.2874 - accuracy: 0.8756
# Epoch 53/100
# 5243/5243 - 0s - loss: 0.2880 - accuracy: 0.8714
# Epoch 54/100
# 5243/5243 - 0s - loss: 0.2861 - accuracy: 0.8774
# Epoch 55/100
# 5243/5243 - 0s - loss: 0.2853 - accuracy: 0.8779
# Epoch 56/100
# 5243/5243 - 0s - loss: 0.2849 - accuracy: 0.8764
# Epoch 57/100
# 5243/5243 - 0s - loss: 0.2857 - accuracy: 0.8755
# Epoch 58/100
# 5243/5243 - 0s - loss: 0.2850 - accuracy: 0.8770
# Epoch 59/100
# 5243/5243 - 0s - loss: 0.2849 - accuracy: 0.8787
# Epoch 60/100
# 5243/5243 - 0s - loss: 0.2851 - accuracy: 0.8798
# Epoch 61/100
# 5243/5243 - 0s - loss: 0.2834 - accuracy: 0.8800
# Epoch 62/100
# 5243/5243 - 0s - loss: 0.2837 - accuracy: 0.8730
# Epoch 63/100
# 5243/5243 - 0s - loss: 0.2820 - accuracy: 0.8808
# Epoch 64/100
# 5243/5243 - 0s - loss: 0.2839 - accuracy: 0.8802
# Epoch 65/100
# 5243/5243 - 0s - loss: 0.2823 - accuracy: 0.8770
# Epoch 66/100
# 5243/5243 - 0s - loss: 0.2822 - accuracy: 0.8789
# Epoch 67/100
# 5243/5243 - 0s - loss: 0.2812 - accuracy: 0.8776
# Epoch 68/100
# 5243/5243 - 0s - loss: 0.2834 - accuracy: 0.8802
# Epoch 69/100
# 5243/5243 - 0s - loss: 0.2815 - accuracy: 0.8825
# Epoch 70/100
# 5243/5243 - 0s - loss: 0.2798 - accuracy: 0.8812
# Epoch 71/100
# 5243/5243 - 0s - loss: 0.2801 - accuracy: 0.8810
# Epoch 72/100
# 5243/5243 - 0s - loss: 0.2796 - accuracy: 0.8793
# Epoch 73/100
# 5243/5243 - 0s - loss: 0.2800 - accuracy: 0.8800
# Epoch 74/100
# 5243/5243 - 0s - loss: 0.2777 - accuracy: 0.8829
# Epoch 75/100
# 5243/5243 - 0s - loss: 0.2790 - accuracy: 0.8821
# Epoch 76/100
# 5243/5243 - 0s - loss: 0.2801 - accuracy: 0.8854
# Epoch 77/100
# 5243/5243 - 0s - loss: 0.2778 - accuracy: 0.8840
# Epoch 78/100
# 5243/5243 - 0s - loss: 0.2779 - accuracy: 0.8783
# Epoch 79/100
# 5243/5243 - 0s - loss: 0.2793 - accuracy: 0.8785
# Epoch 80/100
# 5243/5243 - 0s - loss: 0.2776 - accuracy: 0.8854
# Epoch 81/100
# 5243/5243 - 0s - loss: 0.2769 - accuracy: 0.8861
# Epoch 82/100
# 5243/5243 - 0s - loss: 0.2780 - accuracy: 0.8838
# Epoch 83/100
# 5243/5243 - 0s - loss: 0.2766 - accuracy: 0.8833
# Epoch 84/100
# 5243/5243 - 0s - loss: 0.2769 - accuracy: 0.8804
# Epoch 85/100
# 5243/5243 - 0s - loss: 0.2760 - accuracy: 0.8817
# Epoch 86/100
# 5243/5243 - 0s - loss: 0.2765 - accuracy: 0.8816
# Epoch 87/100
# 5243/5243 - 0s - loss: 0.2762 - accuracy: 0.8819
# Epoch 88/100
# 5243/5243 - 0s - loss: 0.2757 - accuracy: 0.8814
# Epoch 89/100
# 5243/5243 - 0s - loss: 0.2754 - accuracy: 0.8825
# Epoch 90/100
# 5243/5243 - 0s - loss: 0.2742 - accuracy: 0.8848
# Epoch 91/100
# 5243/5243 - 0s - loss: 0.2746 - accuracy: 0.8859
# Epoch 92/100
# 5243/5243 - 0s - loss: 0.2750 - accuracy: 0.8846
# Epoch 93/100
# 5243/5243 - 0s - loss: 0.2758 - accuracy: 0.8838
# Epoch 94/100
# 5243/5243 - 0s - loss: 0.2755 - accuracy: 0.8854
# Epoch 95/100
# 5243/5243 - 0s - loss: 0.2757 - accuracy: 0.8838
# Epoch 96/100
# 5243/5243 - 0s - loss: 0.2735 - accuracy: 0.8852
# Epoch 97/100
# 5243/5243 - 0s - loss: 0.2745 - accuracy: 0.8854
# Epoch 98/100
# 5243/5243 - 0s - loss: 0.2731 - accuracy: 0.8833
# Epoch 99/100
# 5243/5243 - 0s - loss: 0.2758 - accuracy: 0.8844
# Epoch 100/100
# 5243/5243 - 0s - loss: 0.2736 - accuracy: 0.8837

# %% [markdown]
# # Deep Learning

# %%
deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                410
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 2s - loss: 1.0470 - accuracy: 0.4295
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.7803 - accuracy: 0.5649
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.5178 - accuracy: 0.7934
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.4086 - accuracy: 0.8018
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.3820 - accuracy: 0.8081
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3696 - accuracy: 0.8180
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3623 - accuracy: 0.8198
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3547 - accuracy: 0.8251
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3512 - accuracy: 0.8245
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3452 - accuracy: 0.8358
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3401 - accuracy: 0.8404
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3362 - accuracy: 0.8444
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3328 - accuracy: 0.8476
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3284 - accuracy: 0.8524
# Epoch 15/100
# 5243/5243 - 0s - loss: 0.3240 - accuracy: 0.8543
# Epoch 16/100
# 5243/5243 - 0s - loss: 0.3203 - accuracy: 0.8596
# Epoch 17/100
# 5243/5243 - 0s - loss: 0.3170 - accuracy: 0.8579
# Epoch 18/100
# 5243/5243 - 0s - loss: 0.3157 - accuracy: 0.8573
# Epoch 19/100
# 5243/5243 - 0s - loss: 0.3120 - accuracy: 0.8652
# Epoch 20/100
# 5243/5243 - 0s - loss: 0.3111 - accuracy: 0.8648
# Epoch 21/100
# 5243/5243 - 0s - loss: 0.3076 - accuracy: 0.8638
# Epoch 22/100
# 5243/5243 - 0s - loss: 0.3083 - accuracy: 0.8673
# Epoch 23/100
# 5243/5243 - 0s - loss: 0.3034 - accuracy: 0.8688
# Epoch 24/100
# 5243/5243 - 0s - loss: 0.3023 - accuracy: 0.8692
# Epoch 25/100
# 5243/5243 - 0s - loss: 0.3002 - accuracy: 0.8692
# Epoch 26/100
# 5243/5243 - 0s - loss: 0.3001 - accuracy: 0.8688
# Epoch 27/100
# 5243/5243 - 0s - loss: 0.3002 - accuracy: 0.8678
# Epoch 28/100
# 5243/5243 - 0s - loss: 0.2956 - accuracy: 0.8741
# Epoch 29/100
# 5243/5243 - 0s - loss: 0.2954 - accuracy: 0.8705
# Epoch 30/100
# 5243/5243 - 0s - loss: 0.2934 - accuracy: 0.8764
# Epoch 31/100
# 5243/5243 - 0s - loss: 0.2924 - accuracy: 0.8762
# Epoch 32/100
# 5243/5243 - 0s - loss: 0.2930 - accuracy: 0.8735
# Epoch 33/100
# 5243/5243 - 0s - loss: 0.2949 - accuracy: 0.8720
# Epoch 34/100
# 5243/5243 - 0s - loss: 0.2913 - accuracy: 0.8741
# Epoch 35/100
# 5243/5243 - 0s - loss: 0.2909 - accuracy: 0.8751
# Epoch 36/100
# 5243/5243 - 0s - loss: 0.2880 - accuracy: 0.8749
# Epoch 37/100
# 5243/5243 - 0s - loss: 0.2873 - accuracy: 0.8777
# Epoch 38/100
# 5243/5243 - 0s - loss: 0.2864 - accuracy: 0.8779
# Epoch 39/100
# 5243/5243 - 0s - loss: 0.2871 - accuracy: 0.8777
# Epoch 40/100
# 5243/5243 - 0s - loss: 0.2866 - accuracy: 0.8737
# Epoch 41/100
# 5243/5243 - 0s - loss: 0.2877 - accuracy: 0.8785
# Epoch 42/100
# 5243/5243 - 0s - loss: 0.2868 - accuracy: 0.8795
# Epoch 43/100
# 5243/5243 - 0s - loss: 0.2869 - accuracy: 0.8785
# Epoch 44/100
# 5243/5243 - 0s - loss: 0.2834 - accuracy: 0.8823
# Epoch 45/100
# 5243/5243 - 0s - loss: 0.2848 - accuracy: 0.8827
# Epoch 46/100
# 5243/5243 - 0s - loss: 0.2844 - accuracy: 0.8791
# Epoch 47/100
# 5243/5243 - 0s - loss: 0.2912 - accuracy: 0.8730
# Epoch 48/100
# 5243/5243 - 0s - loss: 0.2828 - accuracy: 0.8795
# Epoch 49/100
# 5243/5243 - 0s - loss: 0.2806 - accuracy: 0.8817
# Epoch 50/100
# 5243/5243 - 0s - loss: 0.2795 - accuracy: 0.8806
# Epoch 51/100
# 5243/5243 - 0s - loss: 0.2800 - accuracy: 0.8812
# Epoch 52/100
# 5243/5243 - 0s - loss: 0.2800 - accuracy: 0.8808
# Epoch 53/100
# 5243/5243 - 0s - loss: 0.2776 - accuracy: 0.8823
# Epoch 54/100
# 5243/5243 - 0s - loss: 0.2789 - accuracy: 0.8827
# Epoch 55/100
# 5243/5243 - 0s - loss: 0.2798 - accuracy: 0.8791
# Epoch 56/100
# 5243/5243 - 0s - loss: 0.2774 - accuracy: 0.8827
# Epoch 57/100
# 5243/5243 - 0s - loss: 0.2784 - accuracy: 0.8844
# Epoch 58/100
# 5243/5243 - 0s - loss: 0.2782 - accuracy: 0.8829
# Epoch 59/100
# 5243/5243 - 0s - loss: 0.2763 - accuracy: 0.8816
# Epoch 60/100
# 5243/5243 - 0s - loss: 0.2780 - accuracy: 0.8838
# Epoch 61/100
# 5243/5243 - 0s - loss: 0.2773 - accuracy: 0.8812
# Epoch 62/100
# 5243/5243 - 0s - loss: 0.2753 - accuracy: 0.8858
# Epoch 63/100
# 5243/5243 - 0s - loss: 0.2757 - accuracy: 0.8827
# Epoch 64/100
# 5243/5243 - 0s - loss: 0.2757 - accuracy: 0.8831
# Epoch 65/100
# 5243/5243 - 0s - loss: 0.2747 - accuracy: 0.8806
# Epoch 66/100
# 5243/5243 - 0s - loss: 0.2745 - accuracy: 0.8852
# Epoch 67/100
# 5243/5243 - 0s - loss: 0.2733 - accuracy: 0.8859
# Epoch 68/100
# 5243/5243 - 0s - loss: 0.2739 - accuracy: 0.8863
# Epoch 69/100
# 5243/5243 - 0s - loss: 0.2723 - accuracy: 0.8867
# Epoch 70/100
# 5243/5243 - 0s - loss: 0.2718 - accuracy: 0.8854
# Epoch 71/100
# 5243/5243 - 0s - loss: 0.2753 - accuracy: 0.8837
# Epoch 72/100
# 5243/5243 - 0s - loss: 0.2718 - accuracy: 0.8856
# Epoch 73/100
# 5243/5243 - 0s - loss: 0.2727 - accuracy: 0.8821
# Epoch 74/100
# 5243/5243 - 0s - loss: 0.2702 - accuracy: 0.8863
# Epoch 75/100
# 5243/5243 - 0s - loss: 0.2735 - accuracy: 0.8865
# Epoch 76/100
# 5243/5243 - 0s - loss: 0.2726 - accuracy: 0.8859
# Epoch 77/100
# 5243/5243 - 0s - loss: 0.2719 - accuracy: 0.8856
# Epoch 78/100
# 5243/5243 - 0s - loss: 0.2709 - accuracy: 0.8861
# Epoch 79/100
# 5243/5243 - 0s - loss: 0.2699 - accuracy: 0.8888
# Epoch 80/100
# 5243/5243 - 0s - loss: 0.2717 - accuracy: 0.8840
# Epoch 81/100
# 5243/5243 - 0s - loss: 0.2707 - accuracy: 0.8854
# Epoch 82/100
# 5243/5243 - 0s - loss: 0.2694 - accuracy: 0.8858
# Epoch 83/100
# 5243/5243 - 0s - loss: 0.2682 - accuracy: 0.8879
# Epoch 84/100
# 5243/5243 - 0s - loss: 0.2687 - accuracy: 0.8871
# Epoch 85/100
# 5243/5243 - 0s - loss: 0.2705 - accuracy: 0.8869
# Epoch 86/100
# 5243/5243 - 0s - loss: 0.2681 - accuracy: 0.8856
# Epoch 87/100
# 5243/5243 - 0s - loss: 0.2686 - accuracy: 0.8882
# Epoch 88/100
# 5243/5243 - 0s - loss: 0.2687 - accuracy: 0.8869
# Epoch 89/100
# 5243/5243 - 0s - loss: 0.2682 - accuracy: 0.8892
# Epoch 90/100
# 5243/5243 - 0s - loss: 0.2670 - accuracy: 0.8880
# Epoch 91/100
# 5243/5243 - 0s - loss: 0.2660 - accuracy: 0.8882
# Epoch 92/100
# 5243/5243 - 0s - loss: 0.2685 - accuracy: 0.8856
# Epoch 93/100
# 5243/5243 - 0s - loss: 0.2691 - accuracy: 0.8850
# Epoch 94/100
# 5243/5243 - 0s - loss: 0.2657 - accuracy: 0.8882
# Epoch 95/100
# 5243/5243 - 0s - loss: 0.2658 - accuracy: 0.8882
# Epoch 96/100
# 5243/5243 - 0s - loss: 0.2676 - accuracy: 0.8875
# Epoch 97/100
# 5243/5243 - 0s - loss: 0.2666 - accuracy: 0.8892
# Epoch 98/100
# 5243/5243 - 0s - loss: 0.2670 - accuracy: 0.8856
# Epoch 99/100
# 5243/5243 - 0s - loss: 0.2666 - accuracy: 0.8869
# Epoch 100/100
# 5243/5243 - 0s - loss: 0.2663 - accuracy: 0.8877

# %% [markdown]
# # Compare 2 models (Neural Networks and Deep Learning

# %%
# Neural Networks
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1 - 0s - loss: 0.3326 - accuracy: 0.8759
# Normal Neural Network - Loss: 0.28571121964083657, Accuracy: 0.8758581280708313

# %%
# Deep Learning
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1 - 0s - loss: 0.3461 - accuracy: 0.8747
# Deep Neural Network - Loss: 0.27833433425399207, Accuracy: 0.8747139573097229

# %% [markdown]
# # Save the Model

# %%
# Save your model

#import joblib
#filename = 'ofunkey_normalneural.sav'
#joblib.dump(model, filename)

# %%
# Save Deep_model

#import joblib
#filename2 = 'ofunkey_deeplearning.sav'
#joblib.dump(deep_model, filename2)

# %% [markdown]
# # Conclusion

# %% [markdown]
# The accuracy of Neural Networks model and Deep Learning model is quite close without hyperparameter tuning and less training.
# Neural Network model: 0.8758581280708313
# Deep Learning model:  0.8747139573097229
#
# However, Random Forest model's best score of (0.8930001907304979) seems better than SVM model (0.8706847224871257) when comparing the scores with hyperparameter tuning.
